# %%
# 값을 여러개 출력하기 
print(1, 2, 3)
print("hello", "python")
# Out:
# 1 2 3
# hello python

# %%
## sep로 값 사이에 문자 넣기 
print(1, 2, 3)
print(1, 2, 3, sep=",")
# Out:
# 1 2 3
# 1,2,3

# %%
print("hello", "python")
print("hello", "python", sep="")
# Out:
# hello python
# hellopython

# %%
print(1920, 1080, sep="x")
# Out:
# 1920x1080

# %%
# 줄바꿈 활용
print(1, 2, 3)
print(1, 2, 3, sep="\n")
# Out:
# 1 2 3
# 1
# 2
# 3

# %%
print("1\n2\n3")
# Out:
# 1
# 2
# 3

# %%
## end 사용하기
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
print(1, end="")
print(2, end="")
print(3, end="")
# Out:
# 123

# %%
print(1, end=" ")
print(2, end=" ")
print(3, end=" ")
# Out:
# 1 2 3
