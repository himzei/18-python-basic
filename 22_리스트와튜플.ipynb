# %%
# 리스트에 요소 하나 추가하기 
a = [10, 20, 30]
a.append(500)
a
len(a)
# Out:
# 4

# %%
a = []
a.append(10)
print(a)
# Out:
# [10]

# %%
text = "hello"
text.append("c")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 text = "hello"
# ----> 2 text.append("c")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# 리스트 안에 리스트 추가하기 
a = [10, 20, 30]
a.append([500, 600])
print(a)
# Out:
# [10, 20, 30, [500, 600]]

# %%
len(a)
# Out:
# 4

# %%
# 리스트 확장하기 
a = [10, 20, 30]
a.extend([500, 600])
print(a)
# Out:
# [10, 20, 30, 500, 600]

# %%
len(a)
# Out:
# 5

# %%
# 리스트으 특정 인덱스에 요소 추가하기 
a = [10, 20, 30]
a.insert(2, 500)
print(a)
# Out:
# [10, 20, 500, 30]

# %%
a = [10, 20, 30]
a.insert(0, 500)
a
# Out:
# [500, 10, 20, 30]

# %%
a = [10, 20, 30]
a.insert(len(a), 500)
a
# Out:
# [10, 20, 30, 500]

# %%
a = [10, 20, 30]
a.insert(1, [500, 600])
a
# Out:
# [10, [500, 600], 20, 30]

# %%
a = [10, 20, 30]
a[1:1] = [500, 600]

# %%
a
# Out:
# [10, 500, 600, 20, 30]

# %%
a = [10, 20, 30]
a[1:2] = [500, 600]

# %%
a
# Out:
# [10, 500, 600, 30]

# %%
# 리스트에서 특정 인덱스의 요소를 삭제하기
a = [10, 20, 30]
print(a.pop())
# Out:
# 30

# %%
print(a)
# Out:
# [10, 20]

# %%
a = [10, 20, 30]
print(a.pop(1))
print(a)
# Out:
# 20
# [10, 30]

# %%
a = [10, 20, 30]
del a[1]

# %%
print(a)
# Out:
# [10, 30]

# %%
# 리스트에서 특정 값을 찾아서 삭제하기 
a = [10, 20, 30]
a.remove(20)

# %%
print(a)
# Out:
# [10, 30]

# %%
a = [10, 20, 30, 20]
a.remove(20)

# %%
a.remove(20)
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a.remove(20)
#       2 print(a)
#
# ValueError: list.remove(x): x not in list

# %%
test = [
    [1, 3, 5, 7, 9],
    ["a", "b", "c", "d", "e"], 
    ["1", "2", "3", "4", "5"]
]
len(test)
# Out:
# 3

# %%
for i in test:
    for j in i:
        print(j, end=" ")
# Out:
# 1 3 5 7 9 a b c d e 1 2 3 4 5
