# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
# 비교연산자
3 > 1
# Out:
# True

# %%
# 숫자가 같은지 다른지 비교 
print(10 == 10)
print(10 != 5)
# Out:
# True
# True

# %%
print("Python" == "Python")
print("Python" == "python")
# Out:
# True
# False

# %%
# 부등호 사용하기 
print(10 > 20)
print(10 < 20)
print(10 >= 20)
print(10 <= 20)
# Out:
# False
# True
# False
# True

# %%
print(1 == 1.0)
# print(1 is 1.0)
print(id(1))
print(id(1.0))

# =, ==, ===
# Out:
# True
# 140708485428008
# 1760921397584

# %%
# 논리연산자 사용하기 

print(True and True and True)
print(True and False and True)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
not True
# Out:
# False

# %%
not True and False or not False

False and False or True

False or True
# Out:
# True

# %%
# 논리연산자와 비교 연산자를 함께 사용하기 
print(10 == 10 and 10 != 5)
print(10 > 5 or 10 < 3)
print(not (10 > 5) )
print(not 1 is 1.0 )
# Out:
# True
# True
# False
# True
# <>:5: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:5: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_14740\1525330132.py:5: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   print(not 1 is 1.0 )

# %%
not 10
# Out:
# False

# %%
False > 5
# Out:
# False
